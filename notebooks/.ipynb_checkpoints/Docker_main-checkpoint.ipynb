# %%
from pyspark.sql import SparkSession

# Create a Spark session
spark = SparkSession.builder.appName("sks")\
            .master("spark://spark-master:7077").getOrCreate() #spark://193193aba901:7077

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://0a33746ed079:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>sks</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
dataframe = spark.read.json('s3a://test/orders.json')

average = dataframe.agg({'amount':'avg'})

#average.write.format("csv").option("header", "true").save("s3a://test/json/")

average.show()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dataframe = spark.read.json('s3a://test/orders.json')
#       3 average = dataframe.agg({'amount':'avg'})
#       5 #average.write.format("csv").option("header", "true").save("s3a://test/json/")
#
# File /opt/conda/lib/python3.11/site-packages/pyspark/sql/readwriter.py:425, in DataFrameReader.json(self, path, schema, primitivesAsString, prefersDecimal, allowComments, allowUnquotedFieldNames, allowSingleQuotes, allowNumericLeadingZero, allowBackslashEscapingAnyCharacter, mode, columnNameOfCorruptRecord, dateFormat, timestampFormat, multiLine, allowUnquotedControlChars, lineSep, samplingRatio, dropFieldIfAllNull, encoding, locale, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, allowNonNumericNumbers)
#     423 if type(path) == list:
# ...

# %%
data = spark.range(0, 10)
data.show()
# Out:
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 data = spark.range(0, 10)
# ----> 2 data.show()
#
# ...

# %%
# data1 = spark.read.csv("/opt/file/taxi.csv", header=True)
# data1.limit(3).show()
