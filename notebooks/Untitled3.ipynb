# %%
import findspark findspark.init("/opt/conda")
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("ExternalSpark")
    .master("spark://spark-master:7077")
    .config("spark.driver.bindAddress", "0.0.0.0")
    .config("spark.driver.host", "jupyter-spark")
    .config("spark.driver.port", "4041")
    .config("spark.blockManager.port", "4042")
    .getOrCreate()
)

print("✅ Spark connected:", spark.sparkContext.master)
# Out:
#   Cell In[2], line 1
#     import findspark findspark.init("/opt/conda")
#                      ^
# SyntaxError: invalid syntax

# %%
spark.range(0, 10).show()
